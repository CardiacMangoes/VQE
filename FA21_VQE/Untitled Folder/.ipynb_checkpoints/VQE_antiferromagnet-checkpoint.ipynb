# %%
#save
import dill
dill.dump_session('VQE_ferromagnet.db')

# %%
#load
import dill
import sys
sys.setrecursionlimit(10000)
dill.load_session('VQE_ferromagnet.db')
# Out:
# ---------------------------------------------------------------------------
# RecursionError                            Traceback (most recent call last)
# /var/folders/sw/fz025m194tl2qfdctthgtncw0000gn/T/ipykernel_29509/2603657389.py in <module>
#       3 import sys
#       4 sys.setrecursionlimit(10000)
# ----> 5 dill.load_session('VQE_ferromagnet.db')
#
# ~/opt/anaconda3/envs/ENV_NAME/lib/python3.7/site-packages/dill/_dill.py in load_session(filename, main, **kwds)
#     418         unpickler._main = main
#     419         unpickler._session = True
# --> 420         module = unpickler.load()
#     421         unpickler._session = False
#     422         main.__dict__.update(module.__dict__)
#
# ~/opt/anaconda3/envs/ENV_NAME/lib/python3.7/site-packages/dill/_dill.py in load(self)
#     523
#     524     def load(self): #NOTE: if settings change, need to update attributes
# --> 525         obj = StockUnpickler.load(self)
#     526         if type(obj).__module__ == getattr(_main_module, '__name__', '__main__'):
#     527             if not self._ignore:
#
# ~/opt/anaconda3/envs/ENV_NAME/lib/python3.7/site-packages/qiskit/__init__.py in __getattr__(self, attr)
#      84
#      85     def __getattr__(self, attr):
# ---> 86         if not self.aer:
#      87             try:
#      88                 from qiskit.providers import aer
#
# ... last 1 frames repeated, from the frame below ...
#
# ~/opt/anaconda3/envs/ENV_NAME/lib/python3.7/site-packages/qiskit/__init__.py in __getattr__(self, attr)
#      84
#      85     def __getattr__(self, attr):
# ---> 86         if not self.aer:
#      87             try:
#      88                 from qiskit.providers import aer
#
# RecursionError: maximum recursion depth exceeded

# %%
from qiskit import Aer
from qiskit_nature.converters.second_quantization import QubitConverter
from qiskit_nature.mappers.second_quantization import SpinMapper, DirectMapper, LinearMapper, JordanWignerMapper
from qiskit.opflow import X, Y, Z, I
from qiskit import QuantumCircuit, ClassicalRegister, QuantumRegister
from qiskit.providers.aer import StatevectorSimulator
from qiskit.utils import QuantumInstance
from qiskit_nature.algorithms import VQEUCCFactory

import pylab
import numpy as np
import retworkx as rx
from qiskit_nature.problems.second_quantization.lattice import (
    BoundaryCondition,
    IsingModel,
    FermiHubbardModel,
    HyperCubicLattice,
    Lattice,
    LatticeDrawStyle,
    LineLattice,
    SquareLattice,
    TriangularLattice,
)
# Out:
# Numpy 1.16 has memory leak bug  https://github.com/numpy/numpy/issues/13808
# It is recommended to downgrade to numpy 1.15 or older

# %%
from qiskit.algorithms import VQE
from qiskit.circuit.library import TwoLocal

tl_circuit = TwoLocal(
    rotation_blocks=["h", "rx"],
    entanglement_blocks="cz",
    entanglement="full",
    reps=2,
    parameter_prefix="y",
)

vqe_solver = VQE(
    ansatz=tl_circuit,
    quantum_instance=QuantumInstance(Aer.get_backend("aer_simulator_statevector")),
)

# %%
#Locally Coupled
def convertSpin(ham):
    result = None
    spins = [I, Z, Y, X]
    for c, x, y, z in zip(ham._coeffs, ham.x, ham.y, ham.z):
        spin = x * 3 + y * 2 + z
        pauli = spins[spin[0]]
        for n in range(1, ham.register_length):
            pauli ^= spins[spin[n]]
        pauli *= c
        result = result + pauli if result else pauli
    return result

def makeLatticeIsing(size):
    lattice = LineLattice(size, boundary_condition=BoundaryCondition.PERIODIC)

    t = -1.0  # the interaction parameter
    v = 1.0  # the onsite potential

    ising = IsingModel.uniform_parameters(
        lattice=lattice,
        uniform_interaction=t, #interaction strength -- "hopping term"
        uniform_onsite_potential=v
    )
    return convertSpin(ising.second_q_ops())
print(makeLatticeIsing(3))
# Out:
# -1.0 * ZZI
# - 1.0 * IZZ
# + 1.0 * XII
# + 1.0 * IXI
# + 1.0 * IIX
# - 1.0 * ZIZ

# %%
n = 12
groundStates = [float('inf')] * n
results = [float('inf')] * n
times = [float('inf')] * n

# %%
def findMin(r):
    for i in range(1, n):
        times[i]  = 0
        for _ in range(r):
            ising = makeLatticeIsing(i)
            if ising:
                result = vqe_solver.compute_minimum_eigenvalue(ising)
                if result.eigenvalue < groundStates[i]:
                    results[i] = result
                    groundStates[i] = result.eigenvalue
                    times[i] = result.optimizer_time
                    print(f"Minimum {i:>4}: {np.round(np.real(result.eigenvalue)):<6} time: {round(result.optimizer_time, 2)}")
                else:
                    print(f"Processed {i:>2}:        time: {round(result.optimizer_time, 2)}")

findMin(1)
# Out:
# Minimum    1: -1.0   time: 0.16
# Minimum    2: -1.0   time: 0.09
# Minimum    3: -3.0   time: 0.35
# Minimum    4: -4.0   time: 0.46
# Minimum    5: -5.0   time: 0.6
# Minimum    6: -6.0   time: 1.1
# Minimum    7: -7.0   time: 1.81
# Minimum    8: -4.0   time: 1.78
# Minimum    9: -5.0   time: 2.54
# Minimum   10: -10.0  time: 6.19
# Minimum   11: -11.0  time: 11.92
# Minimum   12: -8.0   time: 115.66

# %%
pylab.plot(list(range(1, len(groundStates))), np.asarray(groundStates[1:], float), label='local')
pylab.xlabel('Size')
pylab.ylabel('Energy')
pylab.title('Ground State Energy')
# Out:
# /Users/riley/opt/anaconda3/envs/ENV_NAME/lib/python3.7/site-packages/ipykernel_launcher.py:1: ComplexWarning: Casting complex values to real discards the imaginary part
#   """Entry point for launching an IPython kernel.
# Text(0.5, 1.0, 'Ground State Energy')

# %%
pylab.plot(list(range(1, len(times))), times[1:], label='local')

pylab.xlabel('Size')
pylab.ylabel('Time')
pylab.title('Optimizer Times')
# Out:
# Text(0.5, 1.0, 'Optimizer Times')
