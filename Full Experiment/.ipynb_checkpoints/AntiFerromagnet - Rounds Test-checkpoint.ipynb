# %%
from qiskit import Aer
from qiskit_nature.converters.second_quantization import QubitConverter
from qiskit_nature.mappers.second_quantization import SpinMapper, DirectMapper, LinearMapper, JordanWignerMapper
from qiskit.opflow import X, Y, Z, I
from qiskit import QuantumCircuit, ClassicalRegister, QuantumRegister
from qiskit.providers.aer import StatevectorSimulator
from qiskit.utils import QuantumInstance
from qiskit_nature.algorithms import VQEUCCFactory

from qiskit.algorithms import VQE
from qiskit.circuit.library import TwoLocal
from qiskit import QuantumCircuit

import pylab
import numpy as np
import retworkx as rx
from qiskit_nature.problems.second_quantization.lattice import (
    BoundaryCondition,
    IsingModel,
    FermiHubbardModel,
    HyperCubicLattice,
    Lattice,
    LatticeDrawStyle,
    LineLattice,
    SquareLattice,
    TriangularLattice,
)

from matplotlib.pyplot import figure
import time
# Out:
# Numpy 1.16 has memory leak bug  https://github.com/numpy/numpy/issues/13808
# It is recommended to downgrade to numpy 1.15 or older

# %%
def findGroundState(pauliSumOp):
    return min(np.linalg.eigh(pauliSumOp.to_matrix())[0])

#Converts SpinOp to PauliSumOp
def convertSpin(ham):
    result = None
    spins = [I, Z, Y, X]
    for c, x, y, z in zip(ham._coeffs, ham.x, ham.y, ham.z):
        spin = x * 3 + y * 2 + z
        pauli = spins[spin[0]]
        for n in range(1, ham.register_length):
            pauli ^= spins[spin[n]]
        pauli *= c
        result = result + pauli if result else pauli
    return result

def makeLatticeIsing(size):
    lattice = LineLattice(size, boundary_condition=BoundaryCondition.PERIODIC)

    t = 1.0  # the interaction parameter corresponds to Z
    v = 1.0  # the onsite potential corresponds to X

    ising = IsingModel.uniform_parameters(
        lattice=lattice,
        uniform_interaction=t, #interaction strength -- "hopping term"
        uniform_onsite_potential=v
    )
    return convertSpin(ising.second_q_ops())

def makeAnsatz(reps = 1, skip = True):
    return TwoLocal(
            rotation_blocks=["rx"],
            entanglement_blocks="rzz",
            entanglement="circular",
            skip_final_rotation_layer = skip,
            reps = reps,
            parameter_prefix="y",)

def findMin(ansatz, reps):
    vqe_solver = VQE(
    ansatz = ansatz,
    quantum_instance=QuantumInstance(Aer.get_backend("aer_simulator_statevector")),)
    
    results = np.full(n, None)
    groundStates = np.full(n, 9999.9)
    times = np.full([n, reps], 0.0)
    for i in range(1, n):
        ising = makeLatticeIsing(i)
        if ising:
            for j in range(reps):
                    result = vqe_solver.compute_minimum_eigenvalue(ising)
                    val = np.real(result.eigenvalue)
                    times[i][j]= result.optimizer_time
                    if val < np.real(groundStates[i]):
                        results[i] = result
                        groundStates[i] = val
                        print(f"Minimum   {i:>2}: {np.round(np.real(result.eigenvalue), 3):<7} " +
                              f"time: {round(result.optimizer_time, 2)}")
                    else:
                        print(f"Processed {i:>2}          time: {round(result.optimizer_time, 2)}")
    return results, groundStates, times

# %%
# define maximum size of system
n = 11
#define number of repetitions
r = 5
# define max number of rounds
s = 5

# %%
# Find True Groundstates of Model
trueGroundStates = np.full(n, 0.0)
trueTimes = np.full(n, 0.0)
for i in range(1,n):
    t1_start = time.time()
    trueGroundStates[i] = findGroundState(makeLatticeIsing(i))
    trueTimes[i] =  time.time() - t1_start
    print(f"{i:>2}: {round(trueGroundStates[i],3):<7} time: {round(trueTimes[i],3)}")
# Out:
#  1: -1.0    time: 0.001
#  2: -2.236  time: 0.005
#  3: -3.464  time: 0.007
#  4: -5.226  time: 0.009
#  5: -6.155  time: 0.011
#  6: -7.727  time: 0.023
#  7: -8.763  time: 0.025
#  8: -10.252 time: 0.034
#  9: -11.343 time: 0.07
# 10: -12.785 time: 0.281

# %%
resultsNR = [None] * 5
groundStatesNR = [None] * 5
timesNR = [None] * 5

# %%
ansatzNR = makeAnsatz(reps = 1)
resultsNR[0], groundStatesNR[0], timesNR[0] = findMin(ansatzNR, r)
# Out:
# Minimum    1: 0.0    time: 0.01
# Processed  1         time: 0.01
# Processed  1         time: 0.01
# Processed  1         time: 0.01
# Processed  1         time: 0.01
# Minimum    2: -1.618 time: 0.08
# Processed  2         time: 0.08
# Processed  2         time: 0.04
# Processed  2         time: 0.04
# Processed  2         time: 0.05
# Minimum    3: -2.484 time: 0.21
# Processed  3         time: 0.15
# Processed  3         time: 0.18
# Processed  3         time: 0.15
# Processed  3         time: 0.15
# Minimum    4: -4.828 time: 0.31
# Minimum    4: -4.828 time: 0.45
# Processed  4         time: 0.47
# Processed  4         time: 0.33
# Processed  4         time: 0.78
# Minimum    5: -4.798 time: 0.51
# Minimum    5: -4.798 time: 1.07
# Processed  5         time: 0.69
# Processed  5         time: 0.57
# Processed  5         time: 0.57
# Minimum    6: -4.668 time: 0.77
# Minimum    6: -7.243 time: 0.4
# Processed  6         time: 0.57
# Processed  6         time: 0.66
# Processed  6         time: 0.77
# Minimum    7: -7.214 time: 1.73
# Minimum    7: -7.214 time: 1.13
# Minimum    7: -7.214 time: 1.43
# Minimum    7: -7.214 time: 0.88
# Minimum    7: -7.214 time: 1.17
# Minimum    8: -9.457 time: 1.71
# Processed  8         time: 2.22
# Minimum    8: -9.657 time: 1.12
# Processed  8         time: 1.28
# Processed  8         time: 1.59
# Minimum    9: -9.628 time: 2.97
# Processed  9         time: 1.74
# Processed  9         time: 1.96
# Processed  9         time: 1.98
# Processed  9         time: 1.91
# Minimum   10: -12.071time: 4.69
# Processed 10         time: 8.86
# Processed 10         time: 5.84
# Processed 10         time: 6.39
# Processed 10         time: 4.93

# %%
for i in range
ansatz = makeAnsatz(reps = 1)
results[0], groundStates[0], timesR[0] = findMin(ansatz, r)
# Out:
# Minimum    1: 0.0    time: 0.01
# Processed  1         time: 0.01
# Processed  1         time: 0.01
# Processed  1         time: 0.01
# Processed  1         time: 0.01
# Minimum    2: -1.618 time: 0.13
# Minimum    2: -1.618 time: 0.08
# Processed  2         time: 0.11
# Processed  2         time: 0.12
# Processed  2         time: 0.1
# Minimum    3: -2.612 time: 0.3
# Minimum    3: -2.612 time: 0.3
# Minimum    3: -2.612 time: 0.28
# Processed  3         time: 0.28
# Processed  3         time: 0.33
# Minimum    4: -4.828 time: 1.67
# Minimum    4: -4.828 time: 1.01
# Processed  4         time: 1.29
# Processed  4         time: 1.27
# Processed  4         time: 1.7
# Minimum    5: -4.929 time: 2.43
# Processed  5         time: 1.67
# Minimum    5: -4.929 time: 1.85
# Processed  5         time: 1.66
# Processed  5         time: 0.98
# Minimum    6: -5.224 time: 1.24
# Minimum    6: -7.243 time: 5.45
# Processed  6         time: 1.35
# Processed  6         time: 1.97
# Minimum    6: -7.243 time: 2.8
# Minimum    7: -7.347 time: 2.79
# Minimum    7: -7.347 time: 3.43
# Processed  7         time: 4.0
# Minimum    7: -7.347 time: 5.8
# Minimum    7: -7.347 time: 5.67
# Minimum    8: -7.545 time: 5.76
# Minimum    8: -7.545 time: 4.74
# Minimum    8: -9.657 time: 8.82
# Processed  8         time: 4.29
# Processed  8         time: 5.49
# Minimum    9: -9.767 time: 11.61
# Minimum    9: -9.768 time: 11.29
# Processed  9         time: 13.73
# Processed  9         time: 6.05
# Processed  9         time: 10.31
# Minimum   10: -9.966 time: 30.15
# Minimum   10: -12.071time: 29.98
# Processed 10         time: 32.26
# Minimum   10: -12.071time: 28.37
# Processed 10         time: 27.95

# %%
ansatzR = makeAnsatz(reps = 2, skip = False)
resultsR[1], groundStatesR[1], timesR[1] = findMin(ansatzR, r)
# Out:
# Minimum    1: 0.0    time: 0.01
# Processed  1         time: 0.01
# Processed  1         time: 0.01
# Processed  1         time: 0.01
# Processed  1         time: 0.01
# Minimum    2: -1.618 time: 0.16
# Processed  2         time: 0.16
# Minimum    2: -1.618 time: 0.18
# Processed  2         time: 0.13
# Minimum    2: -1.618 time: 0.13
# Minimum    3: -2.732 time: 0.56
# Minimum    3: -2.732 time: 0.68
# Processed  3         time: 1.03
# Processed  3         time: 1.06
# Processed  3         time: 1.61
# Minimum    4: -4.969 time: 6.24
# Processed  4         time: 5.14
# Minimum    4: -4.976 time: 5.04
# Processed  4         time: 5.92
# Processed  4         time: 4.71
# Minimum    5: -5.503 time: 7.67
# Processed  5         time: 6.13
# Minimum    5: -5.504 time: 5.98
# Processed  5         time: 7.21
# Processed  5         time: 7.41
# Minimum    6: -7.452 time: 10.59
# Minimum    6: -7.463 time: 8.9
# Processed  6         time: 8.85
# Processed  6         time: 9.43
# Processed  6         time: 9.91
# Minimum    7: -7.936 time: 14.44
# Processed  7         time: 15.11
# Processed  7         time: 15.16
# Processed  7         time: 15.93
# Processed  7         time: 14.81
# Minimum    8: -9.931 time: 21.6
# Minimum    8: -9.935 time: 21.86
# Processed  8         time: 17.69
# Processed  8         time: 17.2
# Minimum    8: -9.94  time: 18.91
# Minimum    9: -10.439time: 27.63
# Processed  9         time: 26.23
# Minimum    9: -10.44 time: 27.48
# Processed  9         time: 30.36
# Processed  9         time: 28.18
# Minimum   10: -11.009time: 60.27
# Processed 10         time: 63.36
# Processed 10         time: 60.23
# Minimum   10: -12.429time: 58.09
# Processed 10         time: 62.83

# %%
from matplotlib.pyplot import figure

figure(figsize=(14, 12), dpi=160)

pylab.plot(list(range(1, n)), np.real(trueGroundStates[1:]), label='true')
pylab.plot(list(range(1, n)), np.real(groundStatesNR[0][1:]), label='1 no rotation')
pylab.plot(list(range(1, n)), np.real(groundStatesNR[1][1:]), label='2 no rotation')
pylab.plot(list(range(1, n)), np.real(groundStatesR[0][1:]), label='1 rotation')
pylab.plot(list(range(1, n)), np.real(groundStatesR[1][1:]), label='2 rotation')

pylab.xlabel('Size')
pylab.xticks(list(range(1, n)))
pylab.ylabel('Energy')
pylab.title('Ground State Energy')
pylab.legend(loc='lower left')

# %%
figure(figsize=(14, 12), dpi=160)

pylab.plot(list(range(1, n)),  trueTimes[1:], label='Numpy')
pylab.plot(list(range(1, n)),  np.sum(timesNR[0][1:], axis = 1), label='No Rotation w/ 1 round')
pylab.plot(list(range(1, n)),  np.sum(timesNR[1][1:], axis = 1), label='No Rotation w/ 2 rounds')
pylab.plot(list(range(1, n)),  np.sum(timesR[0][1:], axis = 1), label='Rotation w/ 1 round')
pylab.plot(list(range(1, n)),  np.sum(timesR[1][1:], axis = 1), label='Rotation w/ 2 rounds')

pylab.xlabel('Size')
pylab.ylabel('Time')
pylab.title('Optimizer Times')
pylab.legend(loc='upper left')

# %%
print(groundStatesR)
# Out:
# [array([ 9.99990000e+03,  0.00000000e+00, -1.61803399e+00, -2.61181727e+00,
#        -4.82842704e+00, -4.92897905e+00, -7.24264052e+00, -7.34743845e+00,
#        -9.65685368e+00, -9.76816945e+00, -1.20710675e+01]), array([ 9.99990000e+03,  0.00000000e+00, -1.61803399e+00, -2.73205077e+00,
#        -4.97578148e+00, -5.50426746e+00, -7.46299932e+00, -7.93639300e+00,
#        -9.93996102e+00, -1.04401567e+01, -1.24286255e+01]), None, None, None]

# %%
print(timesR)
# Out:
# [array([[0.00000000e+00, 0.00000000e+00, 0.00000000e+00, 0.00000000e+00,
#         0.00000000e+00],
#        [1.23558044e-02, 1.29501820e-02, 1.43990517e-02, 1.22859478e-02,
#         1.24590397e-02],
#        [1.33116961e-01, 7.82048702e-02, 1.07846975e-01, 1.17075920e-01,
#         1.03865147e-01],
#        [2.96746016e-01, 3.04502010e-01, 2.84425259e-01, 2.84087896e-01,
#         3.32806110e-01],
#        [1.66673207e+00, 1.00558591e+00, 1.28926802e+00, 1.27399993e+00,
#         1.70397997e+00],
#        [2.43070722e+00, 1.66754985e+00, 1.85285783e+00, 1.66134810e+00,
#         9.77429152e-01],
#        [1.23832202e+00, 5.44739771e+00, 1.34904218e+00, 1.96592426e+00,
#         2.80238986e+00],
#        [2.79222989e+00, 3.43266106e+00, 4.00003195e+00, 5.80054092e+00,
#         5.66688609e+00],
#        [5.75787807e+00, 4.74018693e+00, 8.82363486e+00, 4.29038215e+00,
#         5.48635602e+00],
#        [1.16061492e+01, 1.12933261e+01, 1.37262719e+01, 6.04848623e+00,
#         1.03055108e+01],
#        [3.01464820e+01, 2.99844668e+01, 3.22634168e+01, 2.83682990e+01,
#         2.79549029e+01]]), array([[0.00000000e+00, 0.00000000e+00, 0.00000000e+00, 0.00000000e+00,
#         0.00000000e+00],
#        [1.42409801e-02, 1.14328861e-02, 1.12698078e-02, 1.22029781e-02,
#         1.10948086e-02],
#        [1.63364172e-01, 1.62338018e-01, 1.78209066e-01, 1.27397776e-01,
#         1.27146959e-01],
#        [5.64092159e-01, 6.78120852e-01, 1.03032088e+00, 1.06014514e+00,
#         1.61090279e+00],
#        [6.23620701e+00, 5.13816500e+00, 5.03740525e+00, 5.92253709e+00,
#         4.71141505e+00],
#        [7.66729903e+00, 6.13437414e+00, 5.97534490e+00, 7.21047401e+00,
#         7.41435909e+00],
#        [1.05943429e+01, 8.89564109e+00, 8.85004592e+00, 9.43098998e+00,
#         9.90999293e+00],
#        [1.44359779e+01, 1.51061242e+01, 1.51556499e+01, 1.59328673e+01,
#         1.48083479e+01],
#        [2.16025093e+01, 2.18625600e+01, 1.76873281e+01, 1.72016299e+01,
#         1.89138167e+01],
#        [2.76331100e+01, 2.62293429e+01, 2.74762597e+01, 3.03606431e+01,
#         2.81765590e+01],
#        [6.02671731e+01, 6.33563128e+01, 6.02307930e+01, 5.80944231e+01,
#         6.28289280e+01]]), None, None, None]

# %%
print(groundStatesNR)
# Out:
# [array([ 9.99990000e+03,  0.00000000e+00, -1.61803399e+00, -2.48443532e+00,
#        -4.82842712e+00, -4.79829280e+00, -7.24264030e+00, -7.21372030e+00,
#        -9.65685421e+00, -9.62791553e+00, -1.20710676e+01]), array([ 9.99990000e+03,  0.00000000e+00, -1.61803396e+00, -2.73205069e+00,
#        -4.97606691e+00, -5.46824461e+00, -7.46395149e+00, -7.91463734e+00,
#        -9.92739452e+00, -1.03966891e+01, -1.24363241e+01]), None, None, None]

# %%
print(timesNR)
# Out:
# [array([[0.00000000e+00, 0.00000000e+00, 0.00000000e+00, 0.00000000e+00,
#         0.00000000e+00],
#        [1.10042095e-02, 1.46760941e-02, 1.08001232e-02, 8.52179527e-03,
#         9.38296318e-03],
#        [7.83059597e-02, 8.18040371e-02, 4.35972214e-02, 3.56791019e-02,
#         5.05120754e-02],
#        [2.12924004e-01, 1.50604010e-01, 1.84713364e-01, 1.49183989e-01,
#         1.45041704e-01],
#        [3.05730820e-01, 4.48586941e-01, 4.72543955e-01, 3.29031229e-01,
#         7.75660992e-01],
#        [5.06825209e-01, 1.07310796e+00, 6.94216013e-01, 5.66842079e-01,
#         5.74589252e-01],
#        [7.65600920e-01, 4.00556087e-01, 5.74880123e-01, 6.59720898e-01,
#         7.72279024e-01],
#        [1.73239017e+00, 1.13009930e+00, 1.43333793e+00, 8.78306866e-01,
#         1.16879487e+00],
#        [1.71141696e+00, 2.22370815e+00, 1.11717105e+00, 1.27917695e+00,
#         1.59075093e+00],
#        [2.96670175e+00, 1.73990321e+00, 1.95564008e+00, 1.98427606e+00,
#         1.91057992e+00],
#        [4.68682504e+00, 8.85626578e+00, 5.84170413e+00, 6.39304614e+00,
#         4.93324780e+00]]), array([[0.00000000e+00, 0.00000000e+00, 0.00000000e+00, 0.00000000e+00,
#         0.00000000e+00],
#        [1.20451450e-02, 9.67502594e-03, 9.17983055e-03, 9.82499123e-03,
#         8.86797905e-03],
#        [1.31131172e-01, 1.35998964e-01, 1.32811069e-01, 1.50434971e-01,
#         1.37470007e-01],
#        [7.44253874e-01, 1.38955092e+00, 1.68979979e+00, 6.88031912e-01,
#         8.12799931e-01],
#        [2.91053820e+00, 3.45076394e+00, 1.96390796e+00, 2.60266995e+00,
#         3.39470124e+00],
#        [2.84790707e+00, 5.76634121e+00, 6.28693008e+00, 5.26935697e+00,
#         4.09327197e+00],
#        [8.41193080e+00, 9.35443401e+00, 7.66319513e+00, 3.65274811e+00,
#         8.20960212e+00],
#        [9.90834308e+00, 8.69970894e+00, 9.01929808e+00, 1.08540664e+01,
#         8.28865600e+00],
#        [1.33065650e+01, 1.37279668e+01, 1.43857129e+01, 1.54534850e+01,
#         1.22394259e+01],
#        [1.92310231e+01, 1.86271780e+01, 1.89816968e+01, 1.85566530e+01,
#         2.07425332e+01],
#        [3.28574879e+01, 4.53061719e+01, 4.60203762e+01, 4.99229441e+01,
#         4.72776670e+01]]), None, None, None]
