# %%
import numpy as np
import pylab
from matplotlib.pyplot import figure

import pylab
import matplotlib
from matplotlib.pyplot import figure
from mpl_toolkits import mplot3d
import numpy as np
import matplotlib.pyplot as plt

from qiskit import Aer
from qiskit.opflow import X, Z, Y, I
from qiskit.utils import QuantumInstance, algorithm_globals
from qiskit.algorithms import VQE, NumPyMinimumEigensolver
from qiskit.circuit.library import TwoLocal, QAOAAnsatz

from qiskit.algorithms.optimizers import ADAM, CG, COBYLA, L_BFGS_B, GradientDescent, NELDER_MEAD, \
                                            NFT, POWELL, SLSQP, SPSA, TNC


#Imports Functions for Building Hamiltonains
# %run Utils.ipynb
np.set_printoptions(formatter={'float': '{:0.3f}'.format})

# %% [markdown]
# # Parameters

# %%
#use even number of qubits for Schwinger
N = 2 #qubits
g = 1 #coupling
m = 0 #bare mass
a = 1 #lattice spacing
theta = 0 #topological term

# %% [markdown]
# # Coefficient Matrix

# %%
#Regular
# target_coupling, mixer_coupling = makeSchwinger((g**2)*a / 2, m / 2, 1 / (4 * a))

#Dimensionless
target_coupling, mixer_coupling = makeSchwinger(1, 1 / 2, 1 / (4 * a)) # m/g = 1, x = range(50-100)

print(f"I:\n{target_coupling.constant}")
print(f"\nX:\n{mixer_coupling.X}")
print(f"\nY:\n{mixer_coupling.Y}")
print(f"\nZ:\n{target_coupling.Z}")
# Out:
# I:
# 0
#
# X:
# [[0.000 0.250]
#  [0.250 0.000]]
#
# Y:
# [[0.000 0.250]
#  [0.250 0.000]]
#
# Z:
# [[1.000 0.000]
#  [0.000 -0.500]]

# %%
npme = NumPyMinimumEigensolver()
mixer_hamiltonian = mixer_coupling.getHamiltonian()
mat = mixer_hamiltonian.to_matrix()
print(mat)
min_result = npme.compute_minimum_eigenvalue(operator= mixer_hamiltonian)
print(min_result.eigenvalue.real / N)
print(-1/np.pi)
# Out:
# [[0. +0.j 0. +0.j 0. +0.j 0. +0.j]
#  [0. +0.j 0. +0.j 0.5+0.j 0. +0.j]
#  [0. +0.j 0.5+0.j 0. +0.j 0. +0.j]
#  [0. +0.j 0. +0.j 0. +0.j 0. +0.j]]
# -0.2499999999999999
# -0.3183098861837907

# %% [markdown]
# # Build Hamiltonian
# Converts the matrix representation into a PauliSumOp Hamiltonian in order to be run on VQE

# %%
mixer_hamiltonian = mixer_coupling.getHamiltonian()
target_hamiltonian = target_coupling.getHamiltonian()

complete_hamiltonian = mixer_hamiltonian + target_hamiltonian

print(target_hamiltonian)
print(mixer_hamiltonian)
# Out:
# 1.0 * ZI
# - 0.5 * IZ
# + 0.5 * II
# 0.25 * XX
# + 0.25 * YY
# + 0.0 * II

# %% [markdown]
# # Ansatz

# %%
ansatz = QAOAAnsatz(cost_operator= target_hamiltonian, 
                    reps=1, 
                    initial_state=None, 
                    mixer_operator= mixer_hamiltonian, 
                    name='QAOA')

# %matplotlib inline
ansatz.decompose().draw(output = "mpl", scale = 3)

# %% [markdown]
# # Optimizers

# %%
max_iters = 10000

optimizers = [L_BFGS_B]

#post-processing
optimizers = setOptimizers(optimizers)
# Out:
# ADAM            OFF
# CG              OFF
# COBYLA          OFF
# L_BFGS_B        ON
# GradientDescent OFF
# NELDER_MEAD     OFF
# NFT             OFF
# POWELL          OFF
# SLSQP           OFF
# SPSA            OFF
# TNC             OFF

# %% [markdown]
# # Run VQE

# %%
#options
verbose = False
vqe_iterations = 1

#implementation
converge_cnts = np.zeros([len(optimizers)], dtype=object)
converge_params = np.zeros([len(optimizers)], dtype=object)
converge_vals = np.zeros([len(optimizers)], dtype=object)

for j in range(vqe_iterations):
    for i, optimizer in enumerate(optimizers):
        print('\rOptimizer: {}        '.format(type(optimizer).__name__), end='')
        algorithm_globals.random_seed = 50
        counts = []
        params = []
        values = []
        def store_intermediate_result(eval_count, parameters, mean, std):
            counts.append(eval_count)
            params.append(parameters)
            values.append(mean)

        vqe = VQE(ansatz, optimizer, callback=store_intermediate_result,
                  quantum_instance=QuantumInstance(backend=Aer.get_backend('statevector_simulator')))
        result = vqe.compute_minimum_eigenvalue(operator=complete_hamiltonian)
        if verbose:
            print(f"\n{result}")
        converge_cnts[i] = np.asarray(counts)
        converge_params[i] = np.asarray(params)
        converge_vals[i] = np.asarray(values)
    print(f'\rOptimization {j+1} complete      ');
# Out:
# Optimizer: L_BFGS_B
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# /var/folders/sw/fz025m194tl2qfdctthgtncw0000gn/T/ipykernel_33459/2891360527.py in <module>
#      22         vqe = VQE(ansatz, optimizer, callback=store_intermediate_result,
#      23                   quantum_instance=QuantumInstance(backend=Aer.get_backend('statevector_simulator')))
# ---> 24         result = vqe.compute_minimum_eigenvalue(operator=complete_hamiltonian)
#      25         if verbose:
#      26             print(f"\n{result}")
#
# ~/opt/anaconda3/envs/ENV_NAME/lib/python3.7/site-packages/qiskit/algorithms/minimum_eigen_solvers/vqe.py in compute_minimum_eigenvalue(self, operator, aux_operators)
#     543         try:
#     544             opt_result = self.optimizer.minimize(
# --> 545                 fun=energy_evaluation, x0=initial_point, jac=gradient, bounds=bounds
#     546             )
#     547         except AttributeError:
#
# ~/opt/anaconda3/envs/ENV_NAME/lib/python3.7/site-packages/qiskit/algorithms/optimizers/scipy_optimizer.py in minimize(self, fun, x0, jac, bounds)
#     134             bounds=bounds,
#     135             options=self._options,
# --> 136             **self._kwargs,
#     137         )
#     138         result = OptimizerResult()
#
# ~/opt/anaconda3/envs/ENV_NAME/lib/python3.7/site-packages/scipy/optimize/_minimize.py in minimize(fun, x0, args, method, jac, hess, hessp, bounds, constraints, tol, callback, options)
#     622     elif meth == 'l-bfgs-b':
#     623         return _minimize_lbfgsb(fun, x0, args, jac, bounds,
# --> 624                                 callback=callback, **options)
#     625     elif meth == 'tnc':
#     626         return _minimize_tnc(fun, x0, args, jac, bounds, callback=callback,
#
# ~/opt/anaconda3/envs/ENV_NAME/lib/python3.7/site-packages/scipy/optimize/lbfgsb.py in _minimize_lbfgsb(fun, x0, args, jac, bounds, disp, maxcor, ftol, gtol, eps, maxfun, maxiter, iprint, callback, maxls, finite_diff_rel_step, **unknown_options)
#     358             # until the completion of the current minimization iteration.
#     359             # Overwrite f and g:
# --> 360             f, g = func_and_grad(x)
#     361         elif task_str.startswith(b'NEW_X'):
#     362             # new iteration
#
# ~/opt/anaconda3/envs/ENV_NAME/lib/python3.7/site-packages/scipy/optimize/_differentiable_functions.py in fun_and_grad(self, x)
#     266             self._update_x_impl(x)
#     267         self._update_fun()
# --> 268         self._update_grad()
#     269         return self.f, self.g
#     270
#
# ~/opt/anaconda3/envs/ENV_NAME/lib/python3.7/site-packages/scipy/optimize/_differentiable_functions.py in _update_grad(self)
#     236     def _update_grad(self):
#     237         if not self.g_updated:
# --> 238             self._update_grad_impl()
#     239             self.g_updated = True
#     240
#
# ~/opt/anaconda3/envs/ENV_NAME/lib/python3.7/site-packages/scipy/optimize/_differentiable_functions.py in update_grad()
#     154                 self.ngev += 1
#     155                 self.g = approx_derivative(fun_wrapped, self.x, f0=self.f,
# --> 156                                            **finite_diff_options)
#     157
#     158         self._update_grad_impl = update_grad
#
# ~/opt/anaconda3/envs/ENV_NAME/lib/python3.7/site-packages/scipy/optimize/_numdiff.py in approx_derivative(fun, x0, method, rel_step, abs_step, f0, bounds, sparsity, as_linear_operator, args, kwargs)
#     485         if sparsity is None:
#     486             return _dense_difference(fun_wrapped, x0, f0, h,
# --> 487                                      use_one_sided, method)
#     488         else:
#     489             if not issparse(sparsity) and len(sparsity) == 2:
#
# ~/opt/anaconda3/envs/ENV_NAME/lib/python3.7/site-packages/scipy/optimize/_numdiff.py in _dense_difference(fun, x0, f0, h, use_one_sided, method)
#     555             x = x0 + h_vecs[i]
#     556             dx = x[i] - x0[i]  # Recompute dx as exactly representable number.
# --> 557             df = fun(x) - f0
#     558         elif method == '3-point' and use_one_sided[i]:
#     559             x1 = x0 + h_vecs[i]
#
# ~/opt/anaconda3/envs/ENV_NAME/lib/python3.7/site-packages/scipy/optimize/_numdiff.py in fun_wrapped(x)
#     435
#     436     def fun_wrapped(x):
# --> 437         f = np.atleast_1d(fun(x, *args, **kwargs))
#     438         if f.ndim > 1:
#     439             raise RuntimeError("`fun` return value has "
#
# ~/opt/anaconda3/envs/ENV_NAME/lib/python3.7/site-packages/scipy/optimize/_differentiable_functions.py in fun_wrapped(x)
#     132             # Overwriting results in undefined behaviour because
#     133             # fun(self.x) will change self.x, with the two no longer linked.
# --> 134             return fun(np.copy(x), *args)
#     135
#     136         def update_fun():
#
# ~/opt/anaconda3/envs/ENV_NAME/lib/python3.7/site-packages/qiskit/algorithms/minimum_eigen_solvers/vqe.py in energy_evaluation(parameters)
#     627             start_time = time()
#     628             sampled_expect_op = self._circuit_sampler.convert(expect_op, params=param_bindings)
# --> 629             means = np.real(sampled_expect_op.eval())
#     630
#     631             if self._callback is not None:
#
# ~/opt/anaconda3/envs/ENV_NAME/lib/python3.7/site-packages/qiskit/opflow/list_ops/list_op.py in eval(self, front)
#     431             )
#     432
# --> 433         evals = [op.eval(front) for op in self.oplist]
#     434
#     435         # Handle application of combo_fn for DictStateFn resp VectorStateFn operators
#
# ~/opt/anaconda3/envs/ENV_NAME/lib/python3.7/site-packages/qiskit/opflow/list_ops/list_op.py in <listcomp>(.0)
#     431             )
#     432
# --> 433         evals = [op.eval(front) for op in self.oplist]
#     434
#     435         # Handle application of combo_fn for DictStateFn resp VectorStateFn operators
#
# ~/opt/anaconda3/envs/ENV_NAME/lib/python3.7/site-packages/qiskit/opflow/list_ops/composed_op.py in eval(self, front)
#     139             eval_list = [StateFn(front, is_measurement=True)] + eval_list  # type: ignore
#     140
# --> 141         return reduce(tree_recursive_eval, reversed(eval_list))
#     142
#     143     # Try collapsing list or trees of compositions into a single <Measurement | Op | State>.
#
# ~/opt/anaconda3/envs/ENV_NAME/lib/python3.7/site-packages/qiskit/opflow/list_ops/composed_op.py in tree_recursive_eval(r, l_arg)
#     129                 return [tree_recursive_eval(r_op, l_arg) for r_op in r]
#     130             else:
# --> 131                 return l_arg.eval(r)
#     132
#     133         eval_list = self.oplist.copy()
#
# ~/opt/anaconda3/envs/ENV_NAME/lib/python3.7/site-packages/qiskit/opflow/state_fns/operator_state_fn.py in eval(self, front)
#     249             front = front.eval()
#     250
# --> 251         return front.adjoint().eval(cast(OperatorBase, self.primitive.eval(front))) * self.coeff
#     252
#     253     def sample(self, shots: int = 1024, massive: bool = False, reverse_endianness: bool = False):
#
# ~/opt/anaconda3/envs/ENV_NAME/lib/python3.7/site-packages/qiskit/opflow/primitive_ops/matrix_op.py in eval(self, front)
#     215
#     216         elif isinstance(front, OperatorBase):
# --> 217             new_front = VectorStateFn(self.to_matrix() @ front.to_matrix())
#     218
#     219         return new_front
#
# KeyboardInterrupt:

# %% [markdown]
# # Results Graph

# %%
figure(dpi=120)
# %matplotlib inline
pylab.rcParams['figure.figsize'] = (12, 8)
for i, optimizer in enumerate(optimizers):
    pylab.plot(converge_cnts[i], converge_vals[i], label=type(optimizer).__name__)
pylab.xlabel('Eval count')
pylab.ylabel('Energy')
pylab.title('Energy convergence for various optimizers')
pylab.legend(loc='upper right');

# %% [markdown]
# # Results Statistics
#
# The error is calculated by the following equation
# $$\text{Error} = {\frac{\lvert E_{VQE} - E_{min} \rvert}{\lvert E_{max} - E_{min} \rvert}}$$

# %%
npme = NumPyMinimumEigensolver()
max_result = npme.compute_minimum_eigenvalue(operator= -1 * (complete_hamiltonian))
min_result = npme.compute_minimum_eigenvalue(operator= complete_hamiltonian)

max_energy = max_result.eigenvalue.real * -1
min_energy = min_result.eigenvalue.real
energy_range = abs(max_energy - min_energy)

print(f'Maximum Energy: {max_energy:.5f}')
print(f'Minimum Energy: {min_energy:.5f}')
print(f'Energy Range: {energy_range:.5f}')

for i, optimizer in enumerate(optimizers):
    error = abs(converge_vals[i][-1] - min_energy)/energy_range * 100
    #print the parameters
    print(f"\n{type(optimizer).__name__}")
    print(f"Params: {converge_params[i][-1]}")
    print(f"Energy: {converge_vals[i][-1]}")
    print(f"Error: {error:.5f}%")
# Out:
# Maximum Energy: 23.04542
# Minimum Energy: -4.63806
# Energy Range: 27.68348
#
# COBYLA
# Params: [5.286 6.014]
# Energy: 1.6991098482837672
# Error: 22.89151%
#
# L_BFGS_B
# Params: [6.283 -1.293]
# Energy: 3.7073067166073854
# Error: 30.14565%

# %%
g_range = [np.infty, -np.infty , 0]
b_range = [np.infty, -np.infty , 0]
for i, optimizer in enumerate(optimizers):
    g, b = converge_params[i][:, 0], converge_params[i][:, 1]
    g_range[0] = min(g_range[0], np.floor(min(g)))
    g_range[1] = max(g_range[1], np.ceil(max(g)))
    
    b_range[0] = min(b_range[0], np.floor(min(b)))
    b_range[1] = max(b_range[1], np.ceil(max(b)))

g_range[2] = g_range[1] - g_range[0]
b_range[2] = b_range[1] - b_range[0]

g_range, b_range = list(map(int, g_range)), list(map(int, b_range))

print("Calculated Range")
print(f"Gamma: {g_range[0]} - {g_range[1]} : {g_range[0]}")
print(f"Beta:  {b_range[0]} - {b_range[1]} : {b_range[2]}")
# Out:
# Calculated Range
# Gamma: 4 - 7 : 4
# Beta:  -2 - 7 : 9

# %% [markdown]
# # Energy Landscape

# %%
def calcEnergy(x, y):
    return vqe.get_energy_evaluation(complete_hamiltonian)([x,y])

def renderLandscape(g_range, b_range, quality = 1):
    gamma_range = (g_range[1] - g_range[0]) * quality
    beta_range = (b_range[1] - b_range[0]) * quality

    gamma = np.linspace(g_range[0], g_range[1], gamma_range)
    beta = np.linspace(b_range[0], b_range[1], beta_range)

    gamma, beta = np.meshgrid(gamma, beta)

    energy = np.zeros([beta_range, gamma_range ], dtype=float)

    ttl = beta_range * gamma_range

    print("Rendering...")
    for i in range(beta_range):
        for j in range(gamma_range):
            energy[i,j] = calcEnergy(gamma[i,j], beta[i,j])
            print(f'{((i * gamma_range) + j + 1) / ttl * 100 :3.2f}%', end='\r', flush = True)
    print("\nDone!")   
    
    return gamma, beta, energy

gamma, beta, energy = renderLandscape([0, 26], [0, 26], 1)
# Out:
# Rendering...
# 100.00%
# Done!

# %%
# %matplotlib notebook
colors = ['red', 'maroon', 'green', 'orange', 'purple', 'cyan', 'pink', 'magenta', 'olive']


matplotlib.rcParams['figure.figsize'] = (10, 10)
fig = plt.figure(1)
ax = plt.axes(projection='3d')

sub_min = 0
sub_max = 50

ax.plot_surface(gamma, beta, energy, cmap='viridis',edgecolor='none', alpha = 0.5)

for i, optimizer in enumerate(optimizers):
    ax.scatter(converge_params[i][:, 0], converge_params[i][:, 1], converge_vals[i], color = colors[i], linewidth=1, label=type(optimizer).__name__)
    ax.plot3D(converge_params[i][:, 0], converge_params[i][:, 1], converge_vals[i], color = colors[i], linewidth=1)

ax.set_xlabel('Gamma')
ax.set_ylabel('Beta')
ax.set_zlabel('Energy');

pylab.legend(loc='upper right');
# Out:
# <img src="data:image/png;base64,..." width="720">

# %%
# %matplotlib inline
figure(dpi=200)
plt.contourf(gamma, beta, energy, 100,cmap='viridis');
plt.colorbar();
